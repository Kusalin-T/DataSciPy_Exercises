# %%
# %pip install pandas
# %pip install seaborn

# %%
import pandas as pd
import seaborn as sb
from matplotlib import pyplot as plt

df_sales = pd.read_excel('histograms.xlsx')
df_sales.head(3)
# Out:
#       Name  Exam_Score
# 0    Aarav          45
# 1  Michael          71
# 2    Bilal          59

# %%
sb.histplot(df_sales['Exam_Score'], kde=True)
plt.title('Why does this work?')
plt.xlabel('Exams')
plt.ylabel('Students')
plt.show()

# %%
df=pd.read_excel('scatter_plot.xlsx')
df.head(5)
# Out:
#    area_square_ft  price
# 0             650     55
# 1             800     91
# 2             950     96
# 3            1100    122
# 4             500     34

# %%
sb.scatterplot(data=df, x='area_square_ft',y='price')
# Out:
# <Axes: xlabel='area_square_ft', ylabel='price'>
